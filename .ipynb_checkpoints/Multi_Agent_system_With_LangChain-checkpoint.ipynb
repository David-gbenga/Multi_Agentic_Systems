# %% [markdown]
# # PROJECT OVERVIEW
#
# * Multi-Agentic Stock Analysis Assistant with LangGraph A multi-agent system that autonomously gathers and analyzes stock performance data for Fortune 500 companies, using LangGraph for advanced agent orchestration.
#
# 🎯 Project Objective The goal of this project is to design and build a multi-agent system that automates the collection, processing, and visualization of information and stock performance data on Fortune 500 companies. The system leverages LangGraph’s agentic orchestration to create intelligent agents capable of collaborating and conditionally executing tools for efficient data gathering and insightful analysis.
#
# 🛠️ Tools and Technologies LangGraph Core Tools – Build and orchestrate agentic workflows.
#
# Wikipedia API – Retrieve factual information on companies.
#
# Python – Implement agents and integrate tools.
#
# Git/GitHub – Version control
#
# Features ✅ Built multiple agents using LangGraph’s agentic framework.
#
# ✅ Implemented agent orchestration with conditional tool calls for adaptive behavior.
#
# ✅ Developed one-line agents for lightweight tasks and supervisor agents for complex coordination.
#
# ✅ Integrated Wikipedia API to automatically gather company information.
#
# ✅ Designed and generated insightful visualizations of stock performance data.
#
# ✅ Enabled flexible and modular agent workflows with LangGraph.

# %% [markdown]
# COnfiguration of Environment : Installing the dependencies & Libraries

# %%
# !pip install --quiet wikipedia==1.4.0
# !pip install langchain-core==0.3.59 langgraph==0.4.3 
# !pip install langchain-openai==0.3.16
# !pip install langchain-experimental==0.3.4 
# !pip install  langgraph-supervisor==0.0.21
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-core==0.3.59 in c:\users\admin\appdata\roaming\python\python312\site-packages (0.3.59)
# Requirement already satisfied: langgraph==0.4.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (0.4.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core==0.3.59) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anaconda3\lib\site-packages (from langchain-core==0.3.59) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anaconda3\lib\site-packages (from langchain-core==0.3.59) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anaconda3\lib\site-packages (from langchain-core==0.3.59) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\anaconda3\lib\site-packages (from langchain-core==0.3.59) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core==0.3.59) (4.13.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core==0.3.59) (2.11.2)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph==0.4.3) (2.1.0)
# Requirement already satisfied: langgraph-prebuilt>=0.1.8 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph==0.4.3) (0.1.8)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph==0.4.3) (0.1.72)
# Requirement already satisfied: xxhash<4.0.0,>=3.5.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph==0.4.3) (3.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.59) (2.1)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph==0.4.3) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\anaconda3\lib\site-packages (from langgraph-sdk>=0.1.42->langgraph==0.4.3) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-sdk>=0.1.42->langgraph==0.4.3) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core==0.3.59) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core==0.3.59) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core==0.3.59) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.3.59) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.3.59) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.3.59) (0.4.0)
# Requirement already satisfied: anyio in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph==0.4.3) (4.2.0)
# Requirement already satisfied: certifi in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph==0.4.3) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph==0.4.3) (1.0.2)
# Requirement already satisfied: idna in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph==0.4.3) (3.7)
# Requirement already satisfied: sniffio in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph==0.4.3) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph==0.4.3) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core==0.3.59) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core==0.3.59) (2.2.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai==0.3.16 in c:\users\admin\appdata\roaming\python\python312\site-packages (0.3.16)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-openai==0.3.16) (0.3.59)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-openai==0.3.16) (1.93.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-openai==0.3.16) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (4.13.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (2.11.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.16) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.16) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (3.7)
# Requirement already satisfied: certifi in c:\users\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.58->langchain-openai==0.3.16) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.3.16) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.3.16) (2.2.3)
# Requirement already satisfied: colorama in c:\users\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain-openai==0.3.16) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-experimental==0.3.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-experimental==0.3.4) (0.3.20)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-experimental==0.3.4) (0.3.59)
# Requirement already satisfied: langchain<1.0.0,>=0.3.21 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.3.21)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.3.18)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.26.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (4.13.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (2.11.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (2.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain<1.0.0,>=0.3.21->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.3.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental==0.3.4) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (3.0.1)
# Requirement already satisfied: anyio in c:\users\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.4) (1.0.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langgraph-supervisor==0.0.21 in c:\users\admin\appdata\roaming\python\python312\site-packages (0.0.21)
# Requirement already satisfied: langgraph>=0.3.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-supervisor==0.0.21) (0.4.3)
# Requirement already satisfied: langgraph-prebuilt<0.2.0,>=0.1.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-supervisor==0.0.21) (0.1.8)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.40 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-supervisor==0.0.21) (0.3.59)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (4.13.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (2.11.2)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph>=0.3.5->langgraph-supervisor==0.0.21) (2.1.0)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph>=0.3.5->langgraph-supervisor==0.0.21) (0.1.72)
# Requirement already satisfied: xxhash<4.0.0,>=3.5.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph>=0.3.5->langgraph-supervisor==0.0.21) (3.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (2.1)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\anaconda3\lib\site-packages (from langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (0.4.0)
# Requirement already satisfied: anyio in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (4.2.0)
# Requirement already satisfied: certifi in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (1.0.2)
# Requirement already satisfied: idna in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (3.7)
# Requirement already satisfied: sniffio in c:\users\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph>=0.3.5->langgraph-supervisor==0.0.21) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.40->langgraph-supervisor==0.0.21) (2.2.3)

# %% [markdown]
# ### Building your agent's toolbox
# ![image.png](attachment:bec0f8ec-ae37-42fe-a443-ebfed34eea33.png)
# * Agents use tools to trigger certain actions that could be used in executing some code, retrieving a local file, running a web search, or performing a math calculation.
#
# * The aim of this project is to build an agentic tool that can compile financial information, including summaries, stock performance data, and accompanying visualizations of Fortune 500 companies.
#
# * I will start with a single-agent implementation to kickstart the LangGraph syntax and after which i create the tools for the multi-agent case.
#
# * In total, there are three tools required:
#
# *A tool for retrieving company information from the internet → Wikipedia
# * A tool for retrieving stock performance information from a local CSV file
# * A tool for running Python code to generate the visualizations
# * Each tool should return its tool output, as well as an instruction for the LLM to return FINAL ANSWER if the task has been completed:

# %% [markdown]
#  # Tool 1: Wikipedia search
# * I used the wikipedia Python library to perform Wikipedia searches and return informative summaries about different companies. This tool calls Wikipedia's API in the backend, which doesn't require an API key.
#
# * This library has two functions that we'll use to search and summarize the company information:
#
# wikipedia.search(): Search Wikipedia to return the highest-ranking page titles
# wikipedia.summary(): Fetch a summary from a given page. The sentences argument can be used to control the amount of information (number of sentences) returned.

# %%
from typing import Annotated
import wikipedia
from langchain_core.tools import tool 

@tool # this makes the function a callable langchain tool
def wikipedia_tool( query : Annotated [str, " The wikipedia search to execute to find key summary information"],):
    """Use this to search wikipedia for factual information"""
    # Step 1 : Search using query 
    results =

# %%
from typing import Annotated
import wikipedia
from langchain_core.tools import tool

@tool
def wikipedia_tool(query: Annotated[str, "The wikipedia search to excute to find key summary information."]):
    """Use this to search wikipedia for factual information"""
    #step 1 search using query 
    try:
        results = wikipedia.search(query)

        if not results:
            return "No results found on wikipedia"
    #step 2 Retrieve page title 
        title = results[0]
    # Feth summary 
        summary = wikipedia.summary(title, sentences = 8, auto_suggest = False, redirect = True)
    except BaseException as e:
        return f"Failed to execute . Error: {repr(e)}"

    return_result = f"Successfully excuted : \n Wikipedia: {summary}"

    return ( return_result + "\n\n If you have completed all task respond with FINAL ANSWER")

# %%
# Test langchain tool using a query 

company_name = "Apple Inc."
wiki_summary = wikipedia_tool.invoke(f"{company_name}")
print(wiki_summary)
# Out:
# Successfully excuted :
#  Wikipedia: Apple Inc. is an American multinational corporation and technology company headquartered in Cupertino, California, in Silicon Valley. It is best known for its consumer electronics, software, and services. Founded in 1976 as Apple Computer Company by Steve Jobs, Steve Wozniak and Ronald Wayne, the company was incorporated by Jobs and Wozniak as Apple Computer, Inc. the following year. It was renamed Apple Inc. in 2007 as the company had expanded its focus from computers to consumer electronics. Apple is the largest technology company by revenue, with US$391.04 billion in the 2024 fiscal year.
#
#  If you have completed all task respond with FINAL ANSWER

# %% [markdown]
# ![image.png](attachment:4266c935-d7fb-470f-9db8-38ab46b7f630.png)
# ### 📈 Tool 2: Stock performance data
#
# I created a stock_data_tool to load stock performance data from a local CSV file and filter it depending on the user's query, then return the results.
#
# This tool will use stock _ticker symbols_, which are unique company IDs, to return the relevant information for that company. Here are the companies and symbols that have stock data available in your environment:
#
# | Company Name | Ticker Symbol |
# |--------------|---------------|
# | Apple        | AAPL          |
# | Microsoft    | MSFT          |
# | Amazon       | AMZN          |
# | Meta         | META          |
# | Netflix      | NFLX          |
# | Tesla        | TSLA          |
#
# Note This tool can be adapted  to pull real-time data from an API like Yahoo Finance, rather than the CSVs.
